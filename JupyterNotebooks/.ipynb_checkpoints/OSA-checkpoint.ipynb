# %% [markdown]
# # OSA

# %% [markdown]
# Before running this notebook, please make sure to install
# - plotly (_pip install plotly_)
# - plotly widget for jupyter lab. See instruction [here](https://plotly.com/python/jupyter-lab-tools/)
# - ipywidgets (_pip install ipywidgets_)
# - ipywidgets for juptyer lab (_jupyter labextension install @jupyter-widgets/jupyterlab-manager_)

# %%
import os
import sys
work_dir = os.path.abspath('../')
if not work_dir in sys.path:
    sys.path.insert(0, work_dir)
from pyOSA import Yokogawa, uiOSA, OSAjupyter

OSAjupyter(DEBUG = True)
# Out:
# Debuging mode ON
# ...

# %%
ipywidgets
